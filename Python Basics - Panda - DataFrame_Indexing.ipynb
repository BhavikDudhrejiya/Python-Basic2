# %%
#Importing library
import pandas as pd

# %%
#Loading data
data = pd.read_csv("C:/Users/Bhavik/Desktop/Data Science/1. Linear Regression/3_Insurance_Losses/InsuranceLosses.csv")

# %%
#Selecting rows by their position
data.iloc[:5]
# Out:
#    Policy Number  Age  Years of Driving Experience  Number of Vehicles Gender  \
# 0         150024   24                            5                   1      M
# 1         144880   31                           10                   1      F
# 2         133742   56                           37                   1      M
# 3         151282   52                           31                   1      F
# 4         174407   20                            3                   1      M
#
#    Married  Vehicle Age Fuel Type      Losses
# 0  Married           11         P  203.319595
# 1   Single            6         P  402.197302
# 2  Married            0         D  553.132096
# 3  Married           15         P  292.430579
# 4   Single           15         P  246.540576

# %%
#Selecting rows from 0 to 50
data.iloc[:51]
# Out:
#     Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 0          150024   24                            5                   1
# 1          144880   31                           10                   1
# 2          133742   56                           37                   1
# 3          151282   52                           31                   1
# 4          174407   20                            3                   1
# 5          142548   29                            8                   1
# 6          183396   36                           19                   1
# 7          106838   67                           49                   1
# 8          137434   69                           48                   1
# 9          192628   16                            0                   1
# 10         154894   19                            1                   1
# 11         187293   29                            8                   1
# ...

# %%
#Selecting rows from 21 to 50
data.iloc[21:51]
# Out:
#     Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 21         140896   17                            0                   1
# 22         197555   29                           10                   1
# 23         198709   66                           49                   1
# 24         155134   22                            3                   1
# 25         104183   33                           16                   1
# 26         131927   69                           48                   1
# 27         146242   39                           22                   1
# 28         138988   41                           22                   1
# 29         102189   20                            2                   1
# 30         128861   68                           49                   1
# 31         101564   31                           12                   1
# 32         105052   30                           13                   1
# ...

# %%
#Selecting columns by their position
data.iloc[:,:2]
# Out:
#        Policy Number  Age
# 0             150024   24
# 1             144880   31
# 2             133742   56
# 3             151282   52
# 4             174407   20
# ...              ...  ...
# 15285         189499   61
# 15286         142111   69
# 15287         176444   69
# 15288         180420   22
# 15289         157201   20
#
# [15290 rows x 2 columns]

# %%
#Selecting columns by their position within the range
data.iloc[:,2:5]
# Out:
#        Years of Driving Experience  Number of Vehicles Gender
# 0                                5                   1      M
# 1                               10                   1      F
# 2                               37                   1      M
# 3                               31                   1      F
# 4                                3                   1      M
# ...                            ...                 ...    ...
# 15285                           43                   4      F
# 15286                           48                   4      F
# 15287                           51                   4      F
# 15288                            4                   4      M
# 15289                            2                   4      F
#
# [15290 rows x 3 columns]

# %%
#Selecting columns with their respective numerical values
data[data['Years of Driving Experience']==1]
data[data['Years of Driving Experience']==4]
data[data['Married']=='Single']
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 1             144880   31                           10                   1
# 4             174407   20                            3                   1
# 6             183396   36                           19                   1
# 8             137434   69                           48                   1
# 9             192628   16                            0                   1
# ...              ...  ...                          ...                 ...
# 15281         102285   17                            0                   4
# 15282         175296   30                           11                   4
# 15283         140800   52                           31                   4
# 15284         176376   36                           19                   4
# 15285         189499   61                           43                   4
#
#       Gender Married  Vehicle Age Fuel Type      Losses
# ...

# %%
data
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 0             150024   24                            5                   1
# 1             144880   31                           10                   1
# 2             133742   56                           37                   1
# 3             151282   52                           31                   1
# 4             174407   20                            3                   1
# ...              ...  ...                          ...                 ...
# 15285         189499   61                           43                   4
# 15286         142111   69                           48                   4
# 15287         176444   69                           51                   4
# 15288         180420   22                            4                   4
# 15289         157201   20                            2                   4
#
#       Gender  Married  Vehicle Age Fuel Type      Losses
# ...
